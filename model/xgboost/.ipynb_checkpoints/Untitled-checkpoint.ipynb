# %%
import numpy as np 
import pandas as pd 
import pickle

# %%
importance = pd.read_csv('/home/yihang_toby/model/xgboost/feature_importance.csv',index_col= 0)
feat_cols = list(importance.sort_values(by = '0',ascending = False)[:200].index)

# %%
feat_cols
# Out:
# ['feature_39*abs(feature_113)',
#  'feature_63+feature_120/abs(feature_63)',
#  'feature_44/abs(feature_41)',
#  'feature_43/abs(feature_45)',
#  'feature_44+feature_45*abs(feature_41)',
#  'feature_41+feature_43*abs(feature_43)',
#  'feature_45+feature_63/abs(feature_41)',
#  'feature_31*abs(feature_113)',
#  'feature_45+feature_63',
#  'feature_63+feature_120*abs(feature_44)',
#  'feature_120-feature_45',
#  'feature_45*abs(feature_44)',
#  'feature_42/abs(feature_44)',
#  'feature_45+feature_63/abs(feature_43)',
#  'feature_41+feature_42/abs(feature_41)',
#  'feature_44+feature_45/abs(feature_43)',
#  'feature_44*abs(feature_42)',
#  'feature_41/abs(feature_45)',
#  'feature_42/abs(feature_45)',
#  'feature_45*abs(feature_62)',
#  'feature_41+feature_43/abs(feature_41)',
#  'feature_41/abs(feature_62)',
#  'feature_63-feature_121',
#  'feature_43/abs(feature_41)',
#  'feature_44+feature_63*abs(feature_63)',
#  'feature_43+feature_45/abs(feature_44)',
#  'feature_42*abs(feature_5)',
#  'feature_41/abs(feature_63)',
#  'feature_45+feature_63*abs(feature_43)',
#  'feature_41*abs(feature_45)',
#  'feature_41+feature_63*abs(feature_43)',
#  'feature_41+feature_45*abs(feature_41)',
#  'feature_63+feature_121*abs(feature_63)',
#  'feature_44+feature_45/abs(feature_41)',
#  'feature_41+feature_42/abs(feature_44)',
#  'feature_43+feature_63/abs(feature_43)',
#  'feature_41+feature_43/abs(feature_45)',
#  'feature_62*abs(feature_44)',
#  'feature_44+feature_45',
#  'feature_43+feature_63/abs(feature_63)',
#  'feature_43/abs(feature_42)',
#  'feature_41+feature_63*abs(feature_45)',
#  'feature_41+feature_45/abs(feature_41)',
#  'feature_45*abs(feature_42)',
#  'feature_42-feature_44',
#  'feature_5+feature_39',
#  'feature_42+feature_63*abs(feature_45)',
#  'feature_41+feature_63/abs(feature_41)',
#  'feature_45+feature_62*abs(feature_44)',
#  'feature_42+feature_63/abs(feature_43)',
#  'feature_41+feature_42',
#  'feature_44/abs(feature_62)',
#  'feature_41+feature_45*abs(feature_43)',
#  'feature_42+feature_45*abs(feature_41)',
#  'feature_41-feature_45',
#  'feature_120-feature_121',
#  'feature_63*abs(feature_120)',
#  'feature_63+feature_37',
#  'feature_40',
#  'feature_42+feature_45/abs(feature_44)',
#  'feature_43+feature_62/abs(feature_41)',
#  'feature_42*abs(feature_45)',
#  'feature_45+feature_62/abs(feature_43)',
#  'feature_45+feature_63*abs(feature_44)',
#  'feature_41*abs(feature_44)',
#  'feature_41+feature_42*abs(feature_41)',
#  'feature_41-feature_42',
#  'feature_3+feature_121/abs(feature_44)',
#  'feature_63+feature_121*abs(feature_45)',
#  'feature_42+feature_63*abs(feature_43)',
#  'feature_95/abs(feature_113)',
#  'feature_41+feature_45/abs(feature_44)',
#  'feature_63+feature_37/abs(feature_43)',
#  'feature_42+feature_45',
#  'feature_44-feature_45',
#  'feature_44+feature_45/abs(feature_45)',
#  'feature_41+feature_45/abs(feature_43)',
#  'feature_5+feature_39/abs(feature_44)',
#  'feature_43+feature_45/abs(feature_45)',
#  'feature_43+feature_62*abs(feature_41)',
#  'feature_45*abs(feature_41)',
#  'feature_63-feature_44',
#  'feature_42-feature_45',
#  'feature_41+feature_45*abs(feature_45)',
#  'feature_43/abs(feature_44)',
#  'feature_63/abs(feature_62)',
#  'feature_43+feature_45*abs(feature_45)',
#  'feature_45+feature_63/abs(feature_45)',
#  'feature_63-feature_43',
#  'feature_44/abs(feature_40)',
#  'feature_44+feature_45*abs(feature_43)',
#  'feature_41/abs(feature_42)',
#  'feature_45*abs(feature_63)',
#  'feature_113-feature_31',
#  'feature_62',
#  'feature_77/abs(feature_62)',
#  'feature_41/abs(feature_44)',
#  'feature_42+feature_63/abs(feature_41)',
#  'feature_43+feature_62*abs(feature_63)',
#  'feature_43+feature_62*abs(feature_45)',
#  'feature_41+feature_42/abs(feature_43)',
#  'feature_44+feature_45/abs(feature_63)',
#  'feature_44+feature_45/abs(feature_44)',
#  'feature_44+feature_63/abs(feature_45)',
#  'feature_40+feature_63/abs(feature_44)',
#  'feature_43+feature_45*abs(feature_63)',
#  'feature_41+feature_43*abs(feature_41)',
#  'feature_95/abs(feature_62)',
#  'feature_63/abs(feature_44)',
#  'feature_45+feature_62',
#  'feature_44+feature_95/abs(feature_63)',
#  'feature_39',
#  'feature_43+feature_63*abs(feature_43)',
#  'feature_42+feature_45*abs(feature_44)',
#  'feature_42/abs(feature_43)',
#  'feature_41+feature_63/abs(feature_63)',
#  'feature_43+feature_45/abs(feature_41)',
#  'feature_41+feature_42*abs(feature_43)',
#  'feature_41+feature_45*abs(feature_44)',
#  'feature_44*abs(feature_41)',
#  'feature_44+feature_45*abs(feature_44)',
#  'feature_42*abs(feature_43)',
#  'feature_43+feature_63/abs(feature_41)',
#  'feature_27+feature_39',
#  'feature_42/abs(feature_63)',
#  'feature_41*abs(feature_43)',
#  'feature_41+feature_62*abs(feature_43)',
#  'feature_62/abs(feature_41)',
#  'feature_45+feature_63*abs(feature_45)',
#  'feature_44*abs(feature_45)',
#  'feature_41+feature_42*abs(feature_44)',
#  'feature_121/abs(feature_41)',
#  'feature_27*abs(feature_113)',
#  'feature_43+feature_45',
#  'feature_42*abs(feature_37)',
#  'feature_40+feature_63*abs(feature_45)',
#  'feature_42*abs(feature_41)',
#  'feature_42+feature_121/abs(feature_41)',
#  'feature_41+feature_43*abs(feature_44)',
#  'feature_45+feature_62*abs(feature_41)',
#  'feature_41+feature_45*abs(feature_63)',
#  'feature_43+feature_45*abs(feature_43)',
#  'feature_45+feature_39/abs(feature_41)',
#  'feature_43*abs(feature_121)',
#  'feature_41+feature_43*abs(feature_45)',
#  'feature_45-feature_63',
#  'feature_4-feature_44',
#  'feature_63*abs(feature_45)',
#  'feature_40/abs(feature_42)',
#  'feature_42-feature_43',
#  'feature_63+feature_120/abs(feature_43)',
#  'feature_41+feature_45/abs(feature_63)',
#  'feature_63/abs(feature_41)',
#  'feature_44+feature_63/abs(feature_44)',
#  'feature_44+feature_95/abs(feature_45)',
#  'feature_43+feature_45/abs(feature_63)',
#  'feature_42+feature_63*abs(feature_41)',
#  'feature_41+feature_42/abs(feature_63)',
#  'feature_42+feature_121*abs(feature_63)',
#  'feature_45+feature_62/abs(feature_41)',
#  'feature_42',
#  'feature_43+feature_63/abs(feature_45)',
#  'feature_41*abs(feature_63)',
#  'feature_5/abs(feature_41)',
#  'feature_5+feature_39/abs(feature_41)',
#  'feature_45/abs(feature_41)',
#  'feature_41+feature_62*abs(feature_45)',
#  'feature_3+feature_121/abs(feature_63)',
#  'feature_42+feature_45*abs(feature_43)',
#  'feature_42+feature_45/abs(feature_41)',
#  'feature_44/abs(feature_42)',
#  'feature_5*abs(feature_37)',
#  'feature_3*abs(feature_63)',
#  'feature_121',
#  'feature_39*abs(feature_95)',
#  'feature_42+feature_45/abs(feature_43)',
#  'feature_44+feature_63',
#  'feature_42+feature_45*abs(feature_45)',
#  'feature_45/abs(feature_42)',
#  'feature_41*abs(feature_42)',
#  'feature_45+feature_39*abs(feature_63)',
#  'feature_41*abs(feature_62)',
#  'feature_41+feature_43/abs(feature_43)',
#  'feature_45/abs(feature_44)',
#  'feature_5+feature_39/abs(feature_43)',
#  'feature_45+feature_39*abs(feature_41)',
#  'feature_45+feature_62*abs(feature_63)',
#  'feature_41+feature_45',
#  'feature_41+feature_43',
#  'feature_37/abs(feature_121)',
#  'feature_43-feature_45',
#  'feature_42*abs(feature_44)',
#  'feature_43-feature_62',
#  'feature_41+feature_42/abs(feature_45)',
#  'feature_62*abs(feature_43)',
#  'feature_43+feature_45*abs(feature_41)',
#  'feature_41+feature_39*abs(feature_63)',
#  'feature_44+feature_63/abs(feature_41)',
#  'feature_63-feature_41',
#  'feature_77*abs(feature_63)']

# %%
X = []
for feature in feat_cols:
    if feature.count('feature') == 1:
        pass
#         X.append(data[feature])
    elif feature.count('feature') == 2:
        if '+' in feature:
            feature1,feature2 = feature.split('+')
#             X.append(data[feature1]+data[feature2])
        elif '-' in feature:
            feature1,feature2 = feature.split('-')
#             X.append(data[feature1]-data[feature2])
        elif '*' in feature:
            feature1,feature2 = feature.split('*')
            feature2 = feature2[4:-1]
#             X.append(data[feature1] * abs(data[feature2])))
        else:
            feature1,feature2 = feature.split('/')
            feature2 = feature2[4:-1]
#             X.append(data[feature1] / abs(data[feature2] + 1e-5)))
    else:
        if '+' in feature:
            feature1 = feature.split('+')[0]
            if '/' in feature:
                feature2,feature3 = feature.split('+')[-1].split('/')
                feature3 = feature3[4:-1]
            else:
                feature2,feature3 = feature.split('+')[-1].split('*')
                feature3 = feature3[4:-1]
        else:
            feature1 = feature.split('-')[0]
            if '/' in feature:
                feature2,feature3 = feature.split('+')[-1].split('/')
                feature3 = feature3[4:-1]
            else:
                feature2,feature3 = feature.split('+')[-1].split('*')
                feature3 = feature3[4:-1]
    print(feature1,feature2)
#         method = feature.split('abs')[0][-1]
# Out:
# feature_39 feature_113
# feature_39 feature_113
# feature_44 feature_41
# feature_43 feature_45
# feature_43 feature_45
# feature_43 feature_45
# feature_43 feature_45
# feature_31 feature_113
# feature_45 feature_63
# feature_45 feature_63
# feature_120 feature_45
# feature_45 feature_44
# feature_42 feature_44
# feature_42 feature_44
# feature_42 feature_44
# feature_42 feature_44
# feature_44 feature_42
# feature_41 feature_45
# feature_42 feature_45
# feature_45 feature_62
# feature_45 feature_62
# feature_41 feature_62
# feature_63 feature_121
# feature_43 feature_41
# feature_43 feature_41
# feature_43 feature_41
# feature_42 feature_5
# feature_41 feature_63
# feature_41 feature_63
# feature_41 feature_45
# feature_41 feature_45
# feature_41 feature_45
# feature_41 feature_45
# feature_41 feature_45
# feature_41 feature_45
# feature_41 feature_45
# feature_41 feature_45
# feature_62 feature_44
# feature_44 feature_45
# feature_44 feature_45
# feature_43 feature_42
# feature_43 feature_42
# feature_43 feature_42
# feature_45 feature_42
# feature_42 feature_44
# feature_5 feature_39
# feature_5 feature_39
# feature_5 feature_39
# feature_5 feature_39
# feature_5 feature_39
# feature_41 feature_42
# feature_44 feature_62
# feature_44 feature_62
# feature_44 feature_62
# feature_41 feature_45
# feature_120 feature_121
# feature_63 feature_120
# feature_63 feature_37
# feature_63 feature_37
# feature_63 feature_37
# feature_63 feature_37
# feature_42 feature_45
# feature_42 feature_45
# feature_42 feature_45
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_42
# feature_41 feature_42
# feature_41 feature_42
# feature_41 feature_42
# feature_95 feature_113
# feature_95 feature_113
# feature_95 feature_113
# feature_42 feature_45
# feature_44 feature_45
# feature_44 feature_45
# feature_44 feature_45
# feature_44 feature_45
# feature_44 feature_45
# feature_44 feature_45
# feature_45 feature_41
# feature_63 feature_44
# feature_42 feature_45
# feature_42 feature_45
# feature_43 feature_44
# feature_63 feature_62
# feature_63 feature_62
# feature_63 feature_62
# feature_63 feature_43
# feature_44 feature_40
# feature_44 feature_40
# feature_41 feature_42
# feature_45 feature_63
# feature_113 feature_31
# feature_113 feature_31
# feature_77 feature_62
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_41 feature_44
# feature_95 feature_62
# feature_63 feature_44
# feature_45 feature_62
# feature_45 feature_62
# feature_45 feature_62
# feature_45 feature_62
# feature_45 feature_62
# feature_42 feature_43
# feature_42 feature_43
# feature_42 feature_43
# feature_42 feature_43
# feature_42 feature_43
# feature_44 feature_41
# feature_44 feature_41
# feature_42 feature_43
# feature_42 feature_43
# feature_27 feature_39
# feature_42 feature_63
# feature_41 feature_43
# feature_41 feature_43
# feature_62 feature_41
# feature_62 feature_41
# feature_44 feature_45
# feature_44 feature_45
# feature_121 feature_41
# feature_27 feature_113
# feature_43 feature_45
# feature_42 feature_37
# feature_42 feature_37
# feature_42 feature_41
# feature_42 feature_41
# feature_42 feature_41
# feature_42 feature_41
# feature_42 feature_41
# feature_42 feature_41
# feature_42 feature_41
# feature_43 feature_121
# feature_43 feature_121
# feature_45 feature_63
# feature_4 feature_44
# feature_63 feature_45
# feature_40 feature_42
# feature_42 feature_43
# feature_42 feature_43
# feature_42 feature_43
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_63 feature_41
# feature_41 feature_63
# feature_5 feature_41
# feature_5 feature_41
# feature_45 feature_41
# feature_45 feature_41
# feature_45 feature_41
# feature_45 feature_41
# feature_45 feature_41
# feature_44 feature_42
# feature_5 feature_37
# feature_3 feature_63
# feature_3 feature_63
# feature_39 feature_95
# feature_39 feature_95
# feature_44 feature_63
# feature_44 feature_63
# feature_45 feature_42
# feature_41 feature_42
# feature_41 feature_42
# feature_41 feature_62
# feature_41 feature_62
# feature_45 feature_44
# feature_45 feature_44
# feature_45 feature_44
# feature_45 feature_44
# feature_41 feature_45
# feature_41 feature_43
# feature_37 feature_121
# feature_43 feature_45
# feature_42 feature_44
# feature_43 feature_62
# feature_43 feature_62
# feature_62 feature_43
# feature_62 feature_43
# feature_62 feature_43
# feature_62 feature_43
# feature_63 feature_41
# feature_77 feature_63

# %%
feat_cols[0].count('feature')
# Out:
# 2

# %%
with open('resp_feature_importance1.pickle','rb') as f:
    model = pickle.load(f)
model
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, gamma=None,
#                                     gpu_id=None, importance_type='gain',
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=None,
#                                     missing=nan, monotone_constraints=None,
#                                     n_estimators=100, n_jobs=None,
#                                     num_parallel_tree=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None,
#                                     scale_pos_weight=None, subsample=None,
#                                     tree_method=None, validate_parameters=None,
#                                     verbosity=None),
#              param_grid={'learning_rate': [0.01], 'max_depth': [6, 10, 15],
#                          'min_child_weight': [1], 'n_estimators': [700, 1000],
#                          'n_jobs': [150], 'tree_method': ['gpu_hist']},
#              verbose=3)

# %%
model.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=0,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=700, n_jobs=150, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='gpu_hist', validate_parameters=1, verbosity=None)

# %%
feature_importance = pd.Series(model.best_estimator_.feature_importances_,index=  model.best_estimator_._Booster.feature_names)

# %%
feature_importance.to_csv('feature_importance.csv')

# %%
importance = pd.read_csv('feature_importance.csv',index_col= 0)

# %%
importance.sort_values(by = '0',ascending = False)[:200].index
# Out:
# Index(['feature_39*abs(feature_113)', 'feature_63+feature_120/abs(feature_63)',
#        'feature_44/abs(feature_41)', 'feature_43/abs(feature_45)',
#        'feature_44+feature_45*abs(feature_41)',
#        'feature_41+feature_43*abs(feature_43)',
#        'feature_45+feature_63/abs(feature_41)', 'feature_31*abs(feature_113)',
#        'feature_45+feature_63', 'feature_63+feature_120*abs(feature_44)',
#        ...
#        'feature_43-feature_45', 'feature_42*abs(feature_44)',
#        'feature_43-feature_62', 'feature_41+feature_42/abs(feature_45)',
#        'feature_62*abs(feature_43)', 'feature_43+feature_45*abs(feature_41)',
#        'feature_41+feature_39*abs(feature_63)',
#        'feature_44+feature_63/abs(feature_41)', 'feature_63-feature_41',
#        'feature_77*abs(feature_63)'],
#       dtype='object', length=200)

# %%
feature_importance.sort_values(a
# Out:
# Index(['feature_63/abs(feature_27)', 'feature_44/abs(feature_41)',
#        'feature_44/abs(feature_40)', 'feature_40/abs(feature_44)',
#        'feature_121/abs(feature_62)', 'feature_95/abs(feature_77)',
#        'feature_41/abs(feature_63)', 'feature_41',
#        'feature_95/abs(feature_113)', 'feature_31/abs(feature_113)',
#        'feature_84', 'feature_41/abs(feature_45)',
#        'feature_63/abs(feature_43)', 'feature_42/abs(feature_40)',
#        'feature_43/abs(feature_45)', 'feature_42/abs(feature_44)',
#        'feature_44/abs(feature_42)', 'feature_63/abs(feature_62)',
#        'feature_45', 'feature_121/abs(feature_4)'],
#       dtype='object')

# %%
feature_importanc

# %%
_Booster.feature_names

# %%
model.best_estimator_._Booster.feature_names
# Out:
# ['feature_0',
#  'feature_1',
#  'feature_2',
#  'feature_3',
#  'feature_4',
#  'feature_5',
#  'feature_6',
#  'feature_7',
#  'feature_8',
#  'feature_9',
#  'feature_10',
#  'feature_11',
#  'feature_12',
#  'feature_13',
#  'feature_14',
#  'feature_15',
#  'feature_16',
#  'feature_17',
#  'feature_18',
#  'feature_19',
#  'feature_20',
#  'feature_21',
#  'feature_22',
#  'feature_23',
#  'feature_24',
#  'feature_25',
#  'feature_26',
#  'feature_27',
#  'feature_28',
#  'feature_29',
#  'feature_30',
#  'feature_31',
#  'feature_32',
#  'feature_33',
#  'feature_34',
#  'feature_35',
#  'feature_36',
#  'feature_37',
#  'feature_38',
#  'feature_39',
#  'feature_40',
#  'feature_41',
#  'feature_42',
#  'feature_43',
#  'feature_44',
#  'feature_45',
#  'feature_46',
#  'feature_47',
#  'feature_48',
#  'feature_49',
#  'feature_50',
#  'feature_51',
#  'feature_52',
#  'feature_53',
#  'feature_54',
#  'feature_55',
#  'feature_56',
#  'feature_57',
#  'feature_58',
#  'feature_59',
#  'feature_60',
#  'feature_61',
#  'feature_62',
#  'feature_63',
#  'feature_64',
#  'feature_65',
#  'feature_66',
#  'feature_67',
#  'feature_68',
#  'feature_69',
#  'feature_70',
#  'feature_71',
#  'feature_72',
#  'feature_73',
#  'feature_74',
#  'feature_75',
#  'feature_76',
#  'feature_77',
#  'feature_78',
#  'feature_79',
#  'feature_80',
#  'feature_81',
#  'feature_82',
#  'feature_83',
#  'feature_84',
#  'feature_85',
#  'feature_86',
#  'feature_87',
#  'feature_88',
#  'feature_89',
#  'feature_90',
#  'feature_91',
#  'feature_92',
#  'feature_93',
#  'feature_94',
#  'feature_95',
#  'feature_96',
#  'feature_97',
#  'feature_98',
#  'feature_99',
#  'feature_100',
#  'feature_101',
#  'feature_102',
#  'feature_103',
#  'feature_104',
#  'feature_105',
#  'feature_106',
#  'feature_107',
#  'feature_108',
#  'feature_109',
#  'feature_110',
#  'feature_111',
#  'feature_112',
#  'feature_113',
#  'feature_114',
#  'feature_115',
#  'feature_116',
#  'feature_117',
#  'feature_118',
#  'feature_119',
#  'feature_120',
#  'feature_121',
#  'feature_122',
#  'feature_123',
#  'feature_124',
#  'feature_125',
#  'feature_126',
#  'feature_127',
#  'feature_128',
#  'feature_129',
#  'feature_3/abs(feature_4)',
#  'feature_3/abs(feature_5)',
#  'feature_3/abs(feature_27)',
#  'feature_3/abs(feature_31)',
#  'feature_3/abs(feature_37)',
#  'feature_3/abs(feature_39)',
#  'feature_3/abs(feature_40)',
#  'feature_3/abs(feature_41)',
#  'feature_3/abs(feature_42)',
#  'feature_3/abs(feature_43)',
#  'feature_3/abs(feature_44)',
#  'feature_3/abs(feature_45)',
#  'feature_3/abs(feature_62)',
#  'feature_3/abs(feature_63)',
#  'feature_3/abs(feature_77)',
#  'feature_3/abs(feature_95)',
#  'feature_3/abs(feature_113)',
#  'feature_3/abs(feature_120)',
#  'feature_3/abs(feature_121)',
#  'feature_4/abs(feature_3)',
#  'feature_4/abs(feature_5)',
#  'feature_4/abs(feature_27)',
#  'feature_4/abs(feature_31)',
#  'feature_4/abs(feature_37)',
#  'feature_4/abs(feature_39)',
#  'feature_4/abs(feature_40)',
#  'feature_4/abs(feature_41)',
#  'feature_4/abs(feature_42)',
#  'feature_4/abs(feature_43)',
#  'feature_4/abs(feature_44)',
#  'feature_4/abs(feature_45)',
#  'feature_4/abs(feature_62)',
#  'feature_4/abs(feature_63)',
#  'feature_4/abs(feature_77)',
#  'feature_4/abs(feature_95)',
#  'feature_4/abs(feature_113)',
#  'feature_4/abs(feature_120)',
#  'feature_4/abs(feature_121)',
#  'feature_5/abs(feature_3)',
#  'feature_5/abs(feature_4)',
#  'feature_5/abs(feature_27)',
#  'feature_5/abs(feature_31)',
#  'feature_5/abs(feature_37)',
#  'feature_5/abs(feature_39)',
#  'feature_5/abs(feature_40)',
#  'feature_5/abs(feature_41)',
#  'feature_5/abs(feature_42)',
#  'feature_5/abs(feature_43)',
#  'feature_5/abs(feature_44)',
#  'feature_5/abs(feature_45)',
#  'feature_5/abs(feature_62)',
#  'feature_5/abs(feature_63)',
#  'feature_5/abs(feature_77)',
#  'feature_5/abs(feature_95)',
#  'feature_5/abs(feature_113)',
#  'feature_5/abs(feature_120)',
#  'feature_5/abs(feature_121)',
#  'feature_27/abs(feature_3)',
#  'feature_27/abs(feature_4)',
#  'feature_27/abs(feature_5)',
#  'feature_27/abs(feature_31)',
#  'feature_27/abs(feature_37)',
#  'feature_27/abs(feature_39)',
#  'feature_27/abs(feature_40)',
#  'feature_27/abs(feature_41)',
#  'feature_27/abs(feature_42)',
#  'feature_27/abs(feature_43)',
#  'feature_27/abs(feature_44)',
#  'feature_27/abs(feature_45)',
#  'feature_27/abs(feature_62)',
#  'feature_27/abs(feature_63)',
#  'feature_27/abs(feature_77)',
#  'feature_27/abs(feature_95)',
#  'feature_27/abs(feature_113)',
#  'feature_27/abs(feature_120)',
#  'feature_27/abs(feature_121)',
#  'feature_31/abs(feature_3)',
#  'feature_31/abs(feature_4)',
#  'feature_31/abs(feature_5)',
#  'feature_31/abs(feature_27)',
#  'feature_31/abs(feature_37)',
#  'feature_31/abs(feature_39)',
#  'feature_31/abs(feature_40)',
#  'feature_31/abs(feature_41)',
#  'feature_31/abs(feature_42)',
#  'feature_31/abs(feature_43)',
#  'feature_31/abs(feature_44)',
#  'feature_31/abs(feature_45)',
#  'feature_31/abs(feature_62)',
#  'feature_31/abs(feature_63)',
#  'feature_31/abs(feature_77)',
#  'feature_31/abs(feature_95)',
#  'feature_31/abs(feature_113)',
#  'feature_31/abs(feature_120)',
#  'feature_31/abs(feature_121)',
#  'feature_37/abs(feature_3)',
#  'feature_37/abs(feature_4)',
#  'feature_37/abs(feature_5)',
#  'feature_37/abs(feature_27)',
#  'feature_37/abs(feature_31)',
#  'feature_37/abs(feature_39)',
#  'feature_37/abs(feature_40)',
#  'feature_37/abs(feature_41)',
#  'feature_37/abs(feature_42)',
#  'feature_37/abs(feature_43)',
#  'feature_37/abs(feature_44)',
#  'feature_37/abs(feature_45)',
#  'feature_37/abs(feature_62)',
#  'feature_37/abs(feature_63)',
#  'feature_37/abs(feature_77)',
#  'feature_37/abs(feature_95)',
#  'feature_37/abs(feature_113)',
#  'feature_37/abs(feature_120)',
#  'feature_37/abs(feature_121)',
#  'feature_39/abs(feature_3)',
#  'feature_39/abs(feature_4)',
#  'feature_39/abs(feature_5)',
#  'feature_39/abs(feature_27)',
#  'feature_39/abs(feature_31)',
#  'feature_39/abs(feature_37)',
#  'feature_39/abs(feature_40)',
#  'feature_39/abs(feature_41)',
#  'feature_39/abs(feature_42)',
#  'feature_39/abs(feature_43)',
#  'feature_39/abs(feature_44)',
#  'feature_39/abs(feature_45)',
#  'feature_39/abs(feature_62)',
#  'feature_39/abs(feature_63)',
#  'feature_39/abs(feature_77)',
#  'feature_39/abs(feature_95)',
#  'feature_39/abs(feature_113)',
#  'feature_39/abs(feature_120)',
#  'feature_39/abs(feature_121)',
#  'feature_40/abs(feature_3)',
#  'feature_40/abs(feature_4)',
#  'feature_40/abs(feature_5)',
#  'feature_40/abs(feature_27)',
#  'feature_40/abs(feature_31)',
#  'feature_40/abs(feature_37)',
#  'feature_40/abs(feature_39)',
#  'feature_40/abs(feature_41)',
#  'feature_40/abs(feature_42)',
#  'feature_40/abs(feature_43)',
#  'feature_40/abs(feature_44)',
#  'feature_40/abs(feature_45)',
#  'feature_40/abs(feature_62)',
#  'feature_40/abs(feature_63)',
#  'feature_40/abs(feature_77)',
#  'feature_40/abs(feature_95)',
#  'feature_40/abs(feature_113)',
#  'feature_40/abs(feature_120)',
#  'feature_40/abs(feature_121)',
#  'feature_41/abs(feature_3)',
#  'feature_41/abs(feature_4)',
#  'feature_41/abs(feature_5)',
#  'feature_41/abs(feature_27)',
#  'feature_41/abs(feature_31)',
#  'feature_41/abs(feature_37)',
#  'feature_41/abs(feature_39)',
#  'feature_41/abs(feature_40)',
#  'feature_41/abs(feature_42)',
#  'feature_41/abs(feature_43)',
#  'feature_41/abs(feature_44)',
#  'feature_41/abs(feature_45)',
#  'feature_41/abs(feature_62)',
#  'feature_41/abs(feature_63)',
#  'feature_41/abs(feature_77)',
#  'feature_41/abs(feature_95)',
#  'feature_41/abs(feature_113)',
#  'feature_41/abs(feature_120)',
#  'feature_41/abs(feature_121)',
#  'feature_42/abs(feature_3)',
#  'feature_42/abs(feature_4)',
#  'feature_42/abs(feature_5)',
#  'feature_42/abs(feature_27)',
#  'feature_42/abs(feature_31)',
#  'feature_42/abs(feature_37)',
#  'feature_42/abs(feature_39)',
#  'feature_42/abs(feature_40)',
#  'feature_42/abs(feature_41)',
#  'feature_42/abs(feature_43)',
#  'feature_42/abs(feature_44)',
#  'feature_42/abs(feature_45)',
#  'feature_42/abs(feature_62)',
#  'feature_42/abs(feature_63)',
#  'feature_42/abs(feature_77)',
#  'feature_42/abs(feature_95)',
#  'feature_42/abs(feature_113)',
#  'feature_42/abs(feature_120)',
#  'feature_42/abs(feature_121)',
#  'feature_43/abs(feature_3)',
#  'feature_43/abs(feature_4)',
#  'feature_43/abs(feature_5)',
#  'feature_43/abs(feature_27)',
#  'feature_43/abs(feature_31)',
#  'feature_43/abs(feature_37)',
#  'feature_43/abs(feature_39)',
#  'feature_43/abs(feature_40)',
#  'feature_43/abs(feature_41)',
#  'feature_43/abs(feature_42)',
#  'feature_43/abs(feature_44)',
#  'feature_43/abs(feature_45)',
#  'feature_43/abs(feature_62)',
#  'feature_43/abs(feature_63)',
#  'feature_43/abs(feature_77)',
#  'feature_43/abs(feature_95)',
#  'feature_43/abs(feature_113)',
#  'feature_43/abs(feature_120)',
#  'feature_43/abs(feature_121)',
#  'feature_44/abs(feature_3)',
#  'feature_44/abs(feature_4)',
#  'feature_44/abs(feature_5)',
#  'feature_44/abs(feature_27)',
#  'feature_44/abs(feature_31)',
#  'feature_44/abs(feature_37)',
#  'feature_44/abs(feature_39)',
#  'feature_44/abs(feature_40)',
#  'feature_44/abs(feature_41)',
#  'feature_44/abs(feature_42)',
#  'feature_44/abs(feature_43)',
#  'feature_44/abs(feature_45)',
#  'feature_44/abs(feature_62)',
#  'feature_44/abs(feature_63)',
#  'feature_44/abs(feature_77)',
#  'feature_44/abs(feature_95)',
#  'feature_44/abs(feature_113)',
#  'feature_44/abs(feature_120)',
#  'feature_44/abs(feature_121)',
#  'feature_45/abs(feature_3)',
#  'feature_45/abs(feature_4)',
#  'feature_45/abs(feature_5)',
#  'feature_45/abs(feature_27)',
#  'feature_45/abs(feature_31)',
#  'feature_45/abs(feature_37)',
#  'feature_45/abs(feature_39)',
#  'feature_45/abs(feature_40)',
#  'feature_45/abs(feature_41)',
#  'feature_45/abs(feature_42)',
#  'feature_45/abs(feature_43)',
#  'feature_45/abs(feature_44)',
#  'feature_45/abs(feature_62)',
#  'feature_45/abs(feature_63)',
#  'feature_45/abs(feature_77)',
#  'feature_45/abs(feature_95)',
#  'feature_45/abs(feature_113)',
#  'feature_45/abs(feature_120)',
#  'feature_45/abs(feature_121)',
#  'feature_62/abs(feature_3)',
#  'feature_62/abs(feature_4)',
#  'feature_62/abs(feature_5)',
#  'feature_62/abs(feature_27)',
#  'feature_62/abs(feature_31)',
#  'feature_62/abs(feature_37)',
#  'feature_62/abs(feature_39)',
#  'feature_62/abs(feature_40)',
#  'feature_62/abs(feature_41)',
#  'feature_62/abs(feature_42)',
#  'feature_62/abs(feature_43)',
#  'feature_62/abs(feature_44)',
#  'feature_62/abs(feature_45)',
#  'feature_62/abs(feature_63)',
#  'feature_62/abs(feature_77)',
#  'feature_62/abs(feature_95)',
#  'feature_62/abs(feature_113)',
#  'feature_62/abs(feature_120)',
#  'feature_62/abs(feature_121)',
#  'feature_63/abs(feature_3)',
#  'feature_63/abs(feature_4)',
#  'feature_63/abs(feature_5)',
#  'feature_63/abs(feature_27)',
#  'feature_63/abs(feature_31)',
#  'feature_63/abs(feature_37)',
#  'feature_63/abs(feature_39)',
#  'feature_63/abs(feature_40)',
#  'feature_63/abs(feature_41)',
#  'feature_63/abs(feature_42)',
#  'feature_63/abs(feature_43)',
#  'feature_63/abs(feature_44)',
#  'feature_63/abs(feature_45)',
#  'feature_63/abs(feature_62)',
#  'feature_63/abs(feature_77)',
#  'feature_63/abs(feature_95)',
#  'feature_63/abs(feature_113)',
#  'feature_63/abs(feature_120)',
#  'feature_63/abs(feature_121)',
#  'feature_77/abs(feature_3)',
#  'feature_77/abs(feature_4)',
#  'feature_77/abs(feature_5)',
#  'feature_77/abs(feature_27)',
#  'feature_77/abs(feature_31)',
#  'feature_77/abs(feature_37)',
#  'feature_77/abs(feature_39)',
#  'feature_77/abs(feature_40)',
#  'feature_77/abs(feature_41)',
#  'feature_77/abs(feature_42)',
#  'feature_77/abs(feature_43)',
#  'feature_77/abs(feature_44)',
#  'feature_77/abs(feature_45)',
#  'feature_77/abs(feature_62)',
#  'feature_77/abs(feature_63)',
#  'feature_77/abs(feature_95)',
#  'feature_77/abs(feature_113)',
#  'feature_77/abs(feature_120)',
#  'feature_77/abs(feature_121)',
#  'feature_95/abs(feature_3)',
#  'feature_95/abs(feature_4)',
#  'feature_95/abs(feature_5)',
#  'feature_95/abs(feature_27)',
#  'feature_95/abs(feature_31)',
#  'feature_95/abs(feature_37)',
#  'feature_95/abs(feature_39)',
#  'feature_95/abs(feature_40)',
#  'feature_95/abs(feature_41)',
#  'feature_95/abs(feature_42)',
#  'feature_95/abs(feature_43)',
#  'feature_95/abs(feature_44)',
#  'feature_95/abs(feature_45)',
#  'feature_95/abs(feature_62)',
#  'feature_95/abs(feature_63)',
#  'feature_95/abs(feature_77)',
#  'feature_95/abs(feature_113)',
#  'feature_95/abs(feature_120)',
#  'feature_95/abs(feature_121)',
#  'feature_113/abs(feature_3)',
#  'feature_113/abs(feature_4)',
#  'feature_113/abs(feature_5)',
#  'feature_113/abs(feature_27)',
#  'feature_113/abs(feature_31)',
#  'feature_113/abs(feature_37)',
#  'feature_113/abs(feature_39)',
#  'feature_113/abs(feature_40)',
#  'feature_113/abs(feature_41)',
#  'feature_113/abs(feature_42)',
#  'feature_113/abs(feature_43)',
#  'feature_113/abs(feature_44)',
#  'feature_113/abs(feature_45)',
#  'feature_113/abs(feature_62)',
#  'feature_113/abs(feature_63)',
#  'feature_113/abs(feature_77)',
#  'feature_113/abs(feature_95)',
#  'feature_113/abs(feature_120)',
#  'feature_113/abs(feature_121)',
#  'feature_120/abs(feature_3)',
#  'feature_120/abs(feature_4)',
#  'feature_120/abs(feature_5)',
#  'feature_120/abs(feature_27)',
#  'feature_120/abs(feature_31)',
#  'feature_120/abs(feature_37)',
#  'feature_120/abs(feature_39)',
#  'feature_120/abs(feature_40)',
#  'feature_120/abs(feature_41)',
#  'feature_120/abs(feature_42)',
#  'feature_120/abs(feature_43)',
#  'feature_120/abs(feature_44)',
#  'feature_120/abs(feature_45)',
#  'feature_120/abs(feature_62)',
#  'feature_120/abs(feature_63)',
#  'feature_120/abs(feature_77)',
#  'feature_120/abs(feature_95)',
#  'feature_120/abs(feature_113)',
#  'feature_120/abs(feature_121)',
#  'feature_121/abs(feature_3)',
#  'feature_121/abs(feature_4)',
#  'feature_121/abs(feature_5)',
#  'feature_121/abs(feature_27)',
#  'feature_121/abs(feature_31)',
#  'feature_121/abs(feature_37)',
#  'feature_121/abs(feature_39)',
#  'feature_121/abs(feature_40)',
#  'feature_121/abs(feature_41)',
#  'feature_121/abs(feature_42)',
#  'feature_121/abs(feature_43)',
#  'feature_121/abs(feature_44)',
#  'feature_121/abs(feature_45)',
#  'feature_121/abs(feature_62)',
#  'feature_121/abs(feature_63)',
#  'feature_121/abs(feature_77)',
#  'feature_121/abs(feature_95)',
#  'feature_121/abs(feature_113)',
#  'feature_121/abs(feature_120)']

# %%
.
